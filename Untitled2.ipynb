# %% [markdown]
# <a href="https://colab.research.google.com/github/r1one-22/BEBEK/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


dataSet = pd.read_csv('/content/DataSet_Penjualan.csv')
dataSet
# Out:
#    Jumlah_Produk_Terjual  Pendapatan
# 0                     10        1000
# 1                     15        1500
# 2                     20        2100
# 3                     25        2500
# 4                     30        3000
# 5                     35        3600
# 6                     40        4100
# 7                     45        4600
# 8                     50        5100
# 9                     55        5600

# %% [markdown]
# Dataset ini memiliki 10 baris data dan 2 fitur yaitu "Jumalh_Produk_Terjual" dana "Pendapatan". Variabel target dari dataset ini digunakand untuk melakukan prediksi dengan Regresi linear adalah "Jumalh_Produk_Terjual" sebagai variabel independen dan "Pendapatan" sebagai variabel Dependen

# %%
#Menampilkan 5 bqris pertama
dataSet.head()
# Out:
#    Jumlah_Produk_Terjual  Pendapatan
# 0                     10        1000
# 1                     15        1500
# 2                     20        2100
# 3                     25        2500
# 4                     30        3000

# %%
#Menampilkan informasi dataset
dataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Kode Wilayah  38 non-null     int64
#  1   Wilayah       38 non-null     object
#  2   Jumlah        38 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.0+ KB

# %% [markdown]
# # **Independent Dan Dependent Variabel**

# %%
x = dataSet['Jumlah_Produk_Terjual'] #Sebagai data Independen
y = dataSet['Pendapatan'] #Sebagai data Dependen

#Menampilkan data  independen
x
# Out:
# 0    10
# 1    15
# 2    20
# 3    25
# 4    30
# 5    35
# 6    40
# 7    45
# 8    50
# 9    55
# Name: Jumlah_Produk_Terjual, dtype: int64

# %%
#Menampilkan data dependen
y
# Out:
# 0    1000
# 1    1500
# 2    2100
# 3    2500
# 4    3000
# 5    3600
# 6    4100
# 7    4600
# 8    5100
# 9    5600
# Name: Pendapatan, dtype: int64

# %%
#untuk Mengambil dataset yang sudah dipanggil dengan pandas
x = dataSet[['Jumlah_Produk_Terjual']]
y = dataSet['Pendapatan']


#Untuk membuat hubungan antara  variabael Independen dan Depende
plt.scatter(x, y)
plt.xlabel('Jumlah_Produk_Terjual')
plt.ylabel('Pendapatan')
plt.title('Jumalh_Produk_Terjual vs Pendapatan')
plt.show()

# %%
from sklearn.model_selection import train_test_split

#Unutk melatih dana mengetest data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# # **Data Training**

# %%
#Menampilkan data train x
x_train
# Out:
#    Jumlah_Produk_Terjual
# 5                     35
# 0                     10
# 7                     45
# 2                     20
# 9                     55
# 4                     30
# 3                     25
# 6                     40

# %%
#Menampilkan data train y
y_train
# Out:
# 5    3600
# 0    1000
# 7    4600
# 2    2100
# 9    5600
# 4    3000
# 3    2500
# 6    4100
# Name: Pendapatan, dtype: int64

# %% [markdown]
# # **Data Test**

# %%
#Menampilkan data test x
x_test
# Out:
#    Jumlah_Produk_Terjual
# 8                     50
# 1                     15

# %%
#Menampilkan data test y
y_test
# Out:
# 8    5100
# 1    1500
# Name: Pendapatan, dtype: int64

# %% [markdown]
# # **Model Regresi**

# %%
from sklearn.linear_model import LinearRegression
#Untuk membangun model regresi linear
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # **Model Predict**

# %%
#Untuk Memprediksi nilai y berdasarkan data test x
model.predict(x_test)
# Out:
# array([5101.72413793, 1523.27586207])

# %%
y_prediksi = model.predict(x_test)
y_prediksi
# Out:
# array([5101.72413793, 1523.27586207])

# %%
print('coef: ', model.coef_[0])
print('intercept :', model.intercept_)
# Out:
# coef:  102.24137931034481
# intercept : -10.34482758620652

# %% [markdown]
# Slope menunjukkan seberapa besar  pertumbuhan variabel dependen untuk tiap kenaikan satu unit. Pada dataset ini nilai slope adalah 102.24. Ini berarti untuk setiap kenaikan 1 satuan pendapatan diprediksi meningkat sekitar 102.24
#
# Intercep menunjukkan nilai variabel pendapatan ketika variabel Jumlah_Produk_Tejual bernilai nol. Pada dataset ini nilai intercept adalah -10.34. Seacra ini adalah pendapatan yang diprediksi ketika tidak ada produk yang terjual. Namun, dalam konteks bisnis ini tanpa penjualan atau mengalami rugi.

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_prediksi)
r2 = r2_score(y_test, y_prediksi)

print("Mean Squared Error (MSE):", mse)
print("R-squared (R2):", r2)
# Out:
# Mean Squared Error (MSE): 272.3692033293712
# R-squared (R2): 0.9999159354310712

# %% [markdown]
# Dilihat dari nilai R^2 yang didapat 0.99 yang berarti model sangat baik dalam meprediksi data

# %%
model.score(x_train, y_train)
# Out:
# 0.9992441356577583

# %%
plt.scatter(x_train, y_train, color = 'blue')

#Untuk menampilkan garis regresi
plt.plot(x_train, model.predict(x_train), color = 'red')
plt.xlabel('Kode Wilayah')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# # **Perbandingan data aktual dan garis regresi**

# %%
# Plot data aktual (titik-titik) dan garis regresi
plt.scatter(x_test, y_test, color = 'blue', label = 'Data Aktual')
plt.plot(x_test, y_prediksi, color = 'red', label = 'Garis Regresi')
plt.xlabel('Jumlah_Produk_Terjual')
plt.ylabel('Pendapatan')
plt.title('Regresi Linear: Jumlah_Produk_Terjual vs Pendapatan (Data Test)')
plt.legend()
plt.show()

# Bandingkan hasil prediksi dengan nilai aktual
perbandingan = pd.DataFrame({'Aktual': y_test, 'Prediksi': y_prediksi})
print("\nPerbandingan Nilai Aktual dan Prediksi:")
print(perbandingan)
# Out:
# Perbandingan Nilai Aktual dan Prediksi:
#    Aktual     Prediksi
# 8    5100  5101.724138
# 1    1500  1523.275862

# %% [markdown]
# Berdasarkan nilai R^2 (0.9992) dan skor data latih (0.9999). Kedua skor ini sangat tinggi dan sangat dekat satu sama lain. Skor R-squared yang tinggi mendekati 1 menunjukkan bahwa model menjelaskan sebagian besar variasi dalam variabel dependen. Karena skor pada data latih dan data uji hampir identik dan keduanya sangat tinggi, ini tidak menunjukkan indikasi overfitting maupun underfitting. Model ini tampaknya bekerja dengan sangat baik pada data yang Anda miliki

# %% [markdown]
# Model
#
#
# ```
# # This is formatted as code
# ```
